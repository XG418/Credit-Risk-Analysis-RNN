# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_info = pd.read_csv('/content/drive/MyDrive/GitHub Project/lending_club_info.csv', index_col = 'LoanStatNew')
#有index 就可以索引
data_info.head()
# Out:
#                                                    Description
# LoanStatNew
# loan_amnt    The listed amount of the loan applied for by t...
# term         The number of payments on the loan. Values are...
# int_rate                             Interest Rate on the loan
# installment  The monthly payment owed by the borrower if th...
# grade                                   LC assigned loan grade

# %%
def feat_info(col_name):
  print(data_info.loc[col_name]['Description'])

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %%
df = pd.read_csv('/content/drive/MyDrive/GitHub Project/lending_club_loan_two.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   loan_amnt             396030 non-null  float64
#  1   term                  396030 non-null  object
#  2   int_rate              396030 non-null  float64
#  3   installment           396030 non-null  float64
#  4   grade                 396030 non-null  object
#  5   sub_grade             396030 non-null  object
#  6   emp_title             373103 non-null  object
#  7   emp_length            377729 non-null  object
#  8   home_ownership        396030 non-null  object
#  9   annual_inc            396030 non-null  float64
#  10  verification_status   396030 non-null  object
#  11  issue_d               396030 non-null  object
#  12  loan_status           396030 non-null  object
#  13  purpose               396030 non-null  object
# ...

# %%
df.describe().transpose()
# Out:
#                          count          mean           std     min       25%  \
# loan_amnt             396030.0  14113.888089   8357.441341  500.00   8000.00
# int_rate              396030.0     13.639400      4.472157    5.32     10.49
# installment           396030.0    431.849698    250.727790   16.08    250.33
# annual_inc            396030.0  74203.175798  61637.621158    0.00  45000.00
# dti                   396030.0     17.379514     18.019092    0.00     11.28
# open_acc              396030.0     11.311153      5.137649    0.00      8.00
# pub_rec               396030.0      0.178191      0.530671    0.00      0.00
# revol_bal             396030.0  15844.539853  20591.836109    0.00   6025.00
# revol_util            395754.0     53.791749     24.452193    0.00     35.80
# total_acc             396030.0     25.414744     11.886991    2.00     17.00
# mort_acc              358235.0      1.813991      2.147930    0.00      0.00
# ...

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ...  \
# 0                Marketing  10+ years           RENT    117000.0  ...
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...
# 2             Statistician   < 1 year           RENT     43057.0  ...
# 3          Client Advocate    6 years           RENT     54000.0  ...
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...
#
#   open_acc pub_rec revol_bal revol_util total_acc  initial_list_status  \
# 0     16.0     0.0   36369.0       41.8      25.0                    w
# ...

# %% [markdown]
# # **Exploratory Data Analysis:**

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        'emp_title', 'emp_length', 'home_ownership', 'annual_inc',
#        'verification_status', 'issue_d', 'loan_status', 'purpose', 'title',
#        'dti', 'earliest_cr_line', 'open_acc', 'pub_rec', 'revol_bal',
#        'revol_util', 'total_acc', 'initial_list_status', 'application_type',
#        'mort_acc', 'pub_rec_bankruptcies', 'address'],
#       dtype='object')

# %%
sns.countplot(x = 'loan_status', data = df, palette = 'Set2')
# Out:
# <ipython-input-165-962800a873c9>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x = 'loan_status', data = df, palette = 'Set2')
# <Axes: xlabel='loan_status', ylabel='count'>

# %%
sns.distplot(df['loan_amnt'], kde= False)
# Out:
# <ipython-input-166-acbf7eef400a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['loan_amnt'], kde= False)
# <Axes: xlabel='loan_amnt'>

# %%
df.select_dtypes([float]).corr()
# Out:
#                       loan_amnt  int_rate  installment  annual_inc       dti  \
# loan_amnt              1.000000  0.168921     0.953929    0.336887  0.016636
# int_rate               0.168921  1.000000     0.162758   -0.056771  0.079038
# installment            0.953929  0.162758     1.000000    0.330381  0.015786
# annual_inc             0.336887 -0.056771     0.330381    1.000000 -0.081685
# dti                    0.016636  0.079038     0.015786   -0.081685  1.000000
# open_acc               0.198556  0.011649     0.188973    0.136150  0.136181
# pub_rec               -0.077779  0.060986    -0.067892   -0.013720 -0.017639
# revol_bal              0.328320 -0.011280     0.316455    0.299773  0.063571
# revol_util             0.099911  0.293659     0.123915    0.027871  0.088375
# total_acc              0.223886 -0.036404     0.202430    0.193023  0.102128
# mort_acc               0.222315 -0.082583     0.193694    0.236320 -0.025439
# ...

# %%
plt.figure(figsize = (10,6))
sns.heatmap(df.select_dtypes([float]).corr(), annot=True)
# Out:
# <Axes: >

# %%
feat_info('pub_rec')
feat_info('open_acc')
feat_info('total_acc')
# Out:
# Number of derogatory public records
# The number of open credit lines in the borrower's credit file.
# The total number of credit lines currently in the borrower's credit file

# %%
sns.scatterplot(x='installment', y='loan_amnt', data=df)
# Out:
# <Axes: xlabel='installment', ylabel='loan_amnt'>

# %%
sns.boxplot(x='loan_status', y='loan_amnt', data=df, palette='Set2')
# Out:
# <ipython-input-171-bc64379f12a7>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='loan_status', y='loan_amnt', data=df, palette='Set2')
# <Axes: xlabel='loan_status', ylabel='loan_amnt'>

# %%
#把上面的图像转换成数字
df.groupby('loan_status')['loan_amnt'].describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                  75%      max
# loan_status
# Charged Off  20000.0  40000.0
# Fully Paid   19225.0  40000.0

# %%
sorted(df['grade'].unique())
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
x = sorted(df['sub_grade'].unique())

# %%
sns.countplot(x='grade', data=df, hue= 'loan_status')
# Out:
# <Axes: xlabel='grade', ylabel='count'>

# %%
plt.figure(figsize = (10,6))
sns.countplot(x='sub_grade', data = df, order = x, palette = 'coolwarm', hue = 'loan_status')
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
f_and_g = df[(df['grade']=='G')|(df['grade']=='F')]
plt.figure(figsize = (10,6))
order = sorted(f_and_g['sub_grade'])
sns.countplot(x='sub_grade', data=f_and_g, hue = 'loan_status', order = order, palette = 'coolwarm')
# Out:
# <Axes: xlabel='sub_grade', ylabel='count'>

# %%
df['loan_repaid'] = df['loan_status'].map({"Fully Paid":1, "Charged Off":0})

# %%
df[['loan_repaid', 'loan_status']]
# Out:
#         loan_repaid  loan_status
# 0                 1   Fully Paid
# 1                 1   Fully Paid
# 2                 1   Fully Paid
# 3                 1   Fully Paid
# 4                 0  Charged Off
# ...             ...          ...
# 396025            1   Fully Paid
# 396026            1   Fully Paid
# 396027            1   Fully Paid
# 396028            1   Fully Paid
# 396029            1   Fully Paid
#
# [396030 rows x 2 columns]

# %%
df.select_dtypes(include = [float,int]).corr()['loan_repaid'].drop('loan_repaid').sort_values().plot(kind = 'bar')
# Out:
# <Axes: >

# %% [markdown]
# # **Data Preprocessing**:

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
len(df)
# Out:
# 396030

# %%
100 * df.isnull().sum()/len(df)
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               5.789208
# emp_length              4.621115
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443401
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# loan_repaid             0.000000
# dtype: float64

# %%
feat_info('emp_title')
print('\n')
feat_info('emp_length')
# Out:
# The job title supplied by the Borrower when applying for the loan.*
#
#
# Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %%
df['emp_title'].nunique()
# Out:
# 173105

# %%
df['emp_title'].value_counts()
# Out:
# emp_title
# Teacher                    4389
# Manager                    4250
# Registered Nurse           1856
# RN                         1846
# Supervisor                 1830
#                            ...
# Postman                       1
# McCarthy & Holthus, LLC       1
# jp flooring                   1
# Histology Technologist        1
# Gracon Services, Inc          1
# Name: count, Length: 173105, dtype: int64

# %%
df = df.drop('emp_title', axis=1)

# %%
x = sorted(df['emp_length'].dropna().unique())
x
# Out:
# ['1 year',
#  '10+ years',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '< 1 year']

# %%
x = ['< 1 year',
    '1 year',
 '2 years',
 '3 years',
 '4 years',
 '5 years',
 '6 years',
 '7 years',
 '8 years',
 '9 years',
 '10+ years']

# %%
plt.figure(figsize = (10,6))
sns.countplot(x='emp_length', data=df, order = x, palette = 'rainbow')
# Out:
# <ipython-input-190-2f96377a8938>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='emp_length', data=df, order = x, palette = 'rainbow')
# <Axes: xlabel='emp_length', ylabel='count'>

# %%
plt.figure(figsize = (10,6))
sns.countplot(x='emp_length', data=df, order = x, palette = 'rainbow', hue = 'loan_status')
# Out:
# <Axes: xlabel='emp_length', ylabel='count'>

# %%
e1 = df[df['loan_status']=='Fully Paid'].groupby('emp_length').count()['loan_status']
e1
# Out:
# emp_length
# 1 year        20728
# 10+ years    102826
# 2 years       28903
# 3 years       25483
# 4 years       19344
# 5 years       21403
# 6 years       16898
# 7 years       16764
# 8 years       15339
# 9 years       12244
# < 1 year      25162
# Name: loan_status, dtype: int64

# %%
e2 = df[df['loan_status']=='Charged Off'].groupby('emp_length').count()['loan_status']
e2
# Out:
# emp_length
# 1 year        5154
# 10+ years    23215
# 2 years       6924
# 3 years       6182
# 4 years       4608
# 5 years       5092
# 6 years       3943
# 7 years       4055
# 8 years       3829
# 9 years       3070
# < 1 year      6563
# Name: loan_status, dtype: int64

# %%
plt.title('Chargeoff percentage group by emp_length')
x = e2/(e1+e2)
x.plot(kind = 'bar')
# Out:
# <Axes: title={'center': 'Chargeoff percentage group by emp_length'}, xlabel='emp_length'>

# %%
df = df.drop('emp_length', axis = 1)

# %%
df.isnull().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1756
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %%
df['title']
# Out:
# 0                        Vacation
# 1              Debt consolidation
# 2         Credit card refinancing
# 3         Credit card refinancing
# 4           Credit Card Refinance
#                    ...
# 396025         Debt consolidation
# 396026         Debt consolidation
# 396027       pay off credit cards
# 396028              Loanforpayoff
# 396029          Toxic Debt Payoff
# Name: title, Length: 396030, dtype: object

# %%
df['purpose']
# Out:
# 0                   vacation
# 1         debt_consolidation
# 2                credit_card
# 3                credit_card
# 4                credit_card
#                  ...
# 396025    debt_consolidation
# 396026    debt_consolidation
# 396027    debt_consolidation
# 396028    debt_consolidation
# 396029    debt_consolidation
# Name: purpose, Length: 396030, dtype: object

# %%
df = df.drop('title', axis = 1)

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %%
df['mort_acc'].value_counts()
# Out:
# mort_acc
# 0.0     139777
# 1.0      60416
# 2.0      49948
# 3.0      38049
# 4.0      27887
# 5.0      18194
# 6.0      11069
# 7.0       6052
# 8.0       3121
# 9.0       1656
# 10.0       865
# 11.0       479
# 12.0       264
# 13.0       146
# 14.0       107
# 15.0        61
# 16.0        37
# 17.0        22
# 18.0        18
# 19.0        15
# 20.0        13
# 24.0        10
# 22.0         7
# 21.0         4
# 25.0         4
# 27.0         3
# 32.0         2
# 31.0         2
# 23.0         2
# 26.0         2
# 28.0         1
# 30.0         1
# 34.0         1
# Name: count, dtype: int64

# %%
df.select_dtypes(include = [int,float]).corr()['mort_acc'].sort_values()
# Out:
# int_rate               -0.082583
# dti                    -0.025439
# revol_util              0.007514
# pub_rec                 0.011552
# pub_rec_bankruptcies    0.027239
# loan_repaid             0.073111
# open_acc                0.109205
# installment             0.193694
# revol_bal               0.194925
# loan_amnt               0.222315
# annual_inc              0.236320
# total_acc               0.381072
# mort_acc                1.000000
# Name: mort_acc, dtype: float64

# %%
print('Mean of mort_acc per total_acc')
total_acc_avg = df.groupby('total_acc')['mort_acc'].mean()
total_acc_avg
# Out:
# Mean of mort_acc per total_acc
# total_acc
# 2.0      0.000000
# 3.0      0.052023
# 4.0      0.066743
# 5.0      0.103289
# 6.0      0.151293
#            ...
# 124.0    1.000000
# 129.0    1.000000
# 135.0    3.000000
# 150.0    2.000000
# 151.0    0.000000
# Name: mort_acc, Length: 118, dtype: float64

# %%
def fill_mean(total_acc, mort_acc):
  if np.isnan(mort_acc):
    return total_acc_avg[total_acc]
  else:
    return mort_acc

# %%
df['mort_acc'] = df.apply(lambda x: fill_mean(x['total_acc'], x['mort_acc']), axis=1)
df['mort_acc']
# Out:
# 0         0.000000
# 1         3.000000
# 2         0.000000
# 3         0.000000
# 4         1.000000
#             ...
# 396025    0.000000
# 396026    1.000000
# 396027    0.000000
# 396028    5.000000
# 396029    1.358013
# Name: mort_acc, Length: 396030, dtype: float64

# %%
df.isnull().sum()
# Out:
# loan_amnt                 0
# term                      0
# int_rate                  0
# installment               0
# grade                     0
# sub_grade                 0
# home_ownership            0
# annual_inc                0
# verification_status       0
# issue_d                   0
# loan_status               0
# purpose                   0
# dti                       0
# earliest_cr_line          0
# open_acc                  0
# pub_rec                   0
# revol_bal                 0
# revol_util              276
# total_acc                 0
# initial_list_status       0
# application_type          0
# mort_acc                  0
# pub_rec_bankruptcies    535
# address                   0
# loan_repaid               0
# dtype: int64

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# sub_grade               0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# loan_repaid             0
# dtype: int64

# %% [markdown]
# # **Categorical Variables and Dummy Variables**

# %%
df.select_dtypes([object]).columns #All the column that are non-numeric
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'earliest_cr_line',
#        'initial_list_status', 'application_type', 'address'],
#       dtype='object')

# %%
df['term'] = df['term'].apply(lambda data: data[:3])
df['term']
# Out:
# 0          36
# 1          36
# 2          36
# 3          36
# 4          60
#          ...
# 396025     60
# 396026     36
# 396027     36
# 396028     60
# 396029     36
# Name: term, Length: 395219, dtype: object

# %%
df = df.drop('grade', axis=1)

# %%
dum_sub = pd.get_dummies(df['sub_grade'], drop_first = True)
df = pd.concat([df.drop('sub_grade', axis =1), dum_sub], axis = 1)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'home_ownership',
#        'annual_inc', 'verification_status', 'issue_d', 'loan_status',
#        'purpose', 'dti', 'earliest_cr_line', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'application_type', 'mort_acc', 'pub_rec_bankruptcies', 'address',
#        'loan_repaid', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5',
#        'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2',
#        'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4',
#        'G5'],
#       dtype='object')

# %%
dummy = pd.get_dummies(df[['verification_status', 'application_type','initial_list_status','purpose']], drop_first = True)
df = pd.concat([df.drop(['verification_status', 'application_type','initial_list_status','purpose'],axis =1),dummy], axis=1)

# %%
df.columns
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'home_ownership',
#        'annual_inc', 'issue_d', 'loan_status', 'dti', 'earliest_cr_line',
#        'open_acc', 'pub_rec', 'revol_bal', 'revol_util', 'total_acc',
#        'mort_acc', 'pub_rec_bankruptcies', 'address', 'loan_repaid', 'A2',
#        'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4',
#        'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1',
#        'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4', 'G5',
#        'verification_status_Source Verified', 'verification_status_Verified',
#        'application_type_INDIVIDUAL', 'application_type_JOINT',
#        'initial_list_status_w', 'purpose_credit_card',
#        'purpose_debt_consolidation', 'purpose_educational',
#        'purpose_home_improvement', 'purpose_house', 'purpose_major_purchase',
#        'purpose_medical', 'purpose_moving', 'purpose_other',
#        'purpose_renewable_energy', 'purpose_small_business',
# ...

# %%
df['home_ownership'].value_counts()
# Out:
# home_ownership
# MORTGAGE    198022
# RENT        159395
# OWN          37660
# OTHER          110
# NONE            29
# ANY              3
# Name: count, dtype: int64

# %%
df['home_ownership'] = df['home_ownership'].replace(['NONE','ANY'],'OTHER')
dummy_home = pd.get_dummies(df['home_ownership'], drop_first=True)

# %%
df = pd.concat([df.drop('home_ownership',axis=1), dummy_home], axis = 1)

# %%
df['zip_code'] = df['address'].apply(lambda zip_code: zip_code[-5:])

# %%
dummy_zip = pd.get_dummies(df['zip_code'], drop_first=True)
df = pd.concat([df.drop(['zip_code','address'],axis=1), dummy_zip],axis=1)

# %%
df = df.drop('issue_d', axis=1)

# %%
df['earliest_cr_year'] = df['earliest_cr_line'].apply(lambda date: int(date[-4:]))
df = df.drop('earliest_cr_line', axis =1)

# %% [markdown]
# # **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

# %%
df = df.drop('loan_status', axis=1)

# %%
X = df.drop('loan_repaid', axis=1)
y = df['loan_repaid']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state =101)

# %% [markdown]
# # **Normalizing the Data**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (316175, 78)

# %%
y_train.shape
# Out:
# (316175,)

# %% [markdown]
# # **Creating the Model**

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.constraints import max_norm

# %%
model = Sequential()

model.add(Dense(78, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(39, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(19, activation = 'relu'))
model.add(Dropout(0.2))

model.add(Dense(units=1, activation = 'sigmoid'))

model.compile(loss = 'binary_crossentropy', optimizer = 'adam')

# %%
model.fit(x = X_train,
          y = y_train,
          epochs = 25,
          batch_size = 256,
          validation_data =(X_test,y_test)
)
# Out:
# Epoch 1/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - loss: 0.3553 - val_loss: 0.2649
# Epoch 2/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 12s 6ms/step - loss: 0.2655 - val_loss: 0.2628
# Epoch 3/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - loss: 0.2618 - val_loss: 0.2627
# Epoch 4/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.2619 - val_loss: 0.2621
# Epoch 5/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.2622 - val_loss: 0.2623
# Epoch 6/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 11s 8ms/step - loss: 0.2608 - val_loss: 0.2619
# Epoch 7/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - loss: 0.2585 - val_loss: 0.2618
# Epoch 8/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - loss: 0.2592 - val_loss: 0.2616
# Epoch 9/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 14s 7ms/step - loss: 0.2590 - val_loss: 0.2612
# Epoch 10/25
# 1236/1236 ━━━━━━━━━━━━━━━━━━━━ 9s 6ms/step - loss: 0.2571 - val_loss: 0.2614
# Epoch 11/25
# ...

# %% [markdown]
# # **Evaluating Model Performance.**

# %%
loss = pd.DataFrame(model.history.history)

# %%
loss.plot()
# Out:
# <Axes: >

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
predictions = model.predict(X_test)
# Out:
# 2471/2471 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step

# %%
predictions.shape
# Out:
# (79044, 1)

# %%
predictions = predictions.flatten()

# 大于0.5为1
predictions = (predictions > 0.5).astype(int)

# %%
print(classification_report(y_test,predictions))
print('\n')
print(confusion_matrix(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.45      0.62     15658
#            1       0.88      1.00      0.93     63386
#
#     accuracy                           0.89     79044
#    macro avg       0.92      0.72      0.78     79044
# weighted avg       0.90      0.89      0.87     79044
#
#
#
# [[ 7082  8576]
#  [  272 63114]]

# %% [markdown]
# # **Imbalance Data**

# %%
from imblearn.over_sampling import SMOTE
from sklearn.utils import class_weight

# %%
sm = SMOTE(random_state=42)
X_train_resampled, y_train_resampled= sm.fit_resample(X_train, y_train)

class_weights = class_weight.compute_class_weight('balanced',
                                                  classes = np.unique(y_train_resampled),
                                                  y = y_train_resampled)

# %%
model.fit(x=X_train_resampled,
          y=y_train_resampled,
          epochs=25,
          batch_size=256,
          validation_data=(X_test, y_test),
          class_weight=dict(enumerate(class_weights)))


prediction = model.predict(X_test)


prediction = (prediction > 0.5).astype(int)


print(classification_report(y_test, prediction))
print('\n')
print(confusion_matrix(y_test, prediction))
# Out:
# Epoch 1/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - loss: 0.3546 - val_loss: 0.3474
# Epoch 2/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 12s 5ms/step - loss: 0.3454 - val_loss: 0.3376
# Epoch 3/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.3408 - val_loss: 0.3565
# Epoch 4/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 11s 5ms/step - loss: 0.3382 - val_loss: 0.3712
# Epoch 5/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 21s 6ms/step - loss: 0.3363 - val_loss: 0.3455
# Epoch 6/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 18s 4ms/step - loss: 0.3350 - val_loss: 0.3571
# Epoch 7/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 14s 6ms/step - loss: 0.3343 - val_loss: 0.3581
# Epoch 8/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 28s 10ms/step - loss: 0.3317 - val_loss: 0.3457
# Epoch 9/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 18s 9ms/step - loss: 0.3326 - val_loss: 0.3597
# Epoch 10/25
# 1987/1987 ━━━━━━━━━━━━━━━━━━━━ 15s 6ms/step - loss: 0.3299 - val_loss: 0.3459
# Epoch 11/25
# ...

# %% [markdown]
# # **Prediction**

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
new_customer
# Out:
# loan_amnt           25000.0
# term                     60
# int_rate              18.24
# installment          638.11
# annual_inc          61665.0
#                      ...
# 48052                 False
# 70466                 False
# 86630                 False
# 93700                 False
# earliest_cr_year       1996
# Name: 305323, Length: 78, dtype: object

# %%
import numpy as np

new_customer_numeric = new_customer.values.astype(np.float32)

prediction = model.predict(new_customer_numeric.reshape(1, -1))
print(prediction)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# [[1.]]

# %%
df.iloc[random_ind]['loan_repaid']
# Out:
# 1
